# %% [markdown]
# <a href="https://colab.research.google.com/github/Shranobxtha/MathWorkshop/blob/main/Workshop3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example 1:

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# Task 1: Run and document the effect of these settings have on pyplot’s graph presentation.

# %%
import matplotlib.pyplot as plt
plt.xlim(0,50)
plt.ylim(0,50)

plt.grid()

# %% [markdown]
# Example 2:

# %%
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]
plt.plot(x) #only one parameter ??
plt.show()

# %% [markdown]
# Example 3:

# %%
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]
y=[3,4,5,6]
plt.plot(x, y, marker='o', color='red', linewidth=2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('The Graph')
plt.show()

# %% [markdown]
# Example 4:

# %%
import matplotlib.pyplot as plt
x=[2, 3, 4, 5]
y=[3, 4, 5, 6]
plt.plot(x, y, marker='o', color='blue',label='line 1', linewidth=3)
plt.plot(x, marker='+', color='green',label='line 2', linewidth=2)
#function to add title
plt.title('Example 4')
#Function to label axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.show()

# %% [markdown]
# Task 2:
# The following table shows the different vehicles and the distance covered by them in the span of 5 days. Display the following table in line plot.
#
# a. Plot “days” in X- axis and “distance covered” in Y- axis.
#
# b. Title of the table “bike details in Plot”

# %%
import matplotlib.pyplot as plt
day=[1,2,3,4,5]
enfield=[50,40,70,80,20]
honda=[80,20,20,50,60]
yamaha=[70,20,60,40,60]
ktm=[40,20,30,70,60]
plt.plot(day, enfield, marker='o', color='blue',label='Enfield', linewidth=1)
plt.plot(day, honda, marker='x', color='red',label='Honda', linewidth=1)
plt.plot(day, yamaha, marker='+', color='black',label='Yamaha', linewidth=1)
plt.plot(day, ktm, marker='*', color='orange',label='KTM', linewidth=1)
#function to add title
plt.title('Distance Covered by Bikes(in Km)')
#Function to label axes
plt.xlabel('Days')
plt.ylabel('KM')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.show()

# %% [markdown]
# Example 5: Plotting from a function

# %%
import matplotlib.pyplot as plt

#create a function to calculate y values
def function(x):
  result= 3*x+2
  return result

#defining empty lists
xCoord=[]
yCoord=[]

#loop over 10 values from 0 to 9, and calculate the matching values for #y using the function
for i in range(0,10):
  xCoord.append(i)
  yCoord.append(function(i))
plt.plot(xCoord,yCoord, marker='x',color='red')

#function to add title
plt.title('Example 5')

#Function to label axes plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# function for the visibility of grid plt.grid()
plt.show()

# %% [markdown]
# Example 5: Sub plot

# %%
import matplotlib.pyplot as plt

# plot a line, implicitly creating a subplot(111)
x=[1,2,3]
y=[4,5,6]
#plt.subplot(nRows,nColumns,index)
# nrows/nColumns number of rows/columns of graphs in the output section
#index position of the graph
plt.subplot(2,2,1)
#subplot(2,2,1) means there will be 2 graphs in row and 2 in columns and index 1 means this graph will be at the first position
plt.plot(x,y, marker='*', color='red')
plt.subplot(2,2,2)
plt.plot(x,y, marker='x', color='green')
plt.subplot(2,2,3)
plt.plot(x,y, marker='^', color='blue')
plt.subplot(2,2,4)
plt.plot(x,y, marker='+', color='yellow')

# %% [markdown]
# Plot the trigonometric function
#
# 1. SINE in interval [−4𝜋,4𝜋], i.e., 𝑦 = sin(𝑥), −4𝜋 ≤ 𝑥 ≤4𝜋.

# %%
# Import necessary modules
# Using math module for pi and sin function
import matplotlib.pyplot as plt
import math

# Step 1: Generate equidistant x-coordinates between the given interval
# Lists for coordinates
x = []
y = []

# Define start, end, and step size for x increment
start = -4 * math.pi
end = 4 * math.pi
step = 0.1 # Controls smoothness of the graph
i = start
while i <= end:
  x.append(i) # Store x-coordinate

# Step 2: Calculate the y-coordinate using sin function for each x
  y.append(math.sin(i))
  i += step

# Step 3: Plot the graph using calculated coordinates
# Label the graph properly
plt.plot(x, y, color="red", label="sin function")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("y = sin(x) ,-4π<= x <= 4π")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# CIRCLE
# 1. Plot a circle with center at (a, b) and radius r. The values of a, b, and r can be chosen appropriately.
#
# Note: To get better result, we use the parametric equation of circle, which is given by:
#
# · 𝑥 =(𝑟cos(𝜃)+𝑎) and
#
# · 𝑦 = (𝑟sin(𝜃)+𝑏) , where 0 ≤ 𝜃 ≤2𝜋
# # Task : Plot a circle with center at (a,b) and radius =r

# %%
import matplotlib.pyplot as plt
import math

# for a=b=2 and r = 4:
# Circle equation: x^2 + y^2 = r^2
# Paramateric equation:
# x =r*cos(theta) + a , and y = r*sin(theta) + b

x =[] # List to store x values
y= [] # List to store y values
r = 4
center = [2,2]

# paramater theta start value
theta_start = 0.0
# parameter Theta end value (bit more than 2pi)
theta_end = 2*math.pi

# step sizes to sample the paramater Theta
step_size= 0.125

#math.ceil() → round up to nearest integer
# Number of samples
steps = math.ceil((theta_end-theta_start)/step_size)

# initialize the theta
# variable to increment Theta by each step
theta = theta_start

# for loop to calculate x and y value at each steps
for i in range(0,steps):
  x.append(r*math.cos(theta)+center[0])
  y.append(r*math.sin(theta)+center[1])
  theta += step_size

# create figure in new window
plt.figure()

# plot a dot a center
plt.plot(center[0],center[1],'.')

plt.plot(x,y,'-')
plt.grid()
plt.xlabel("X")
plt.ylabel("Y")

#plt.gca() → Get the current figure (axes object) for handling
ax =plt.gca()

#ensures 1 unit in x = 1 unit in y
#Without this ,figure is stretched(ircle could appear as an ellipse)
ax.set_aspect('equal',adjustable='box')
plt.show()

# %% [markdown]
# ELLIPSE
# 1. Plot an Ellipse ( ((x-p)^2)/a^2) +( ((y-q)^2)/b^2) =1 with center at (p, q), length of minor axis 2a and major axis 2b. The values of p, q, a, and b can be chosen appropriately.
#
# Note : parametric equations of an ellipse centered at (p,q) with semi-major axis b and semi-minor axis a are:
#
# · x = a cos(θ)+p,
#
# · y = b sin(θ) +q

# %%
# importing a library

import matplotlib.pyplot as plt

import math

# Lists to store x and y values

x = []

y = []

# Ellipse parameters

a=3 # semi-minor axis

b=5 # semi-major axis

center =[2,2] # center (p,q)


# Parameter theta

theta_start = 0.0

theta_end = 3*math.pi # make more than 2*pi

step_size = 0.125


# Number of samples

steps = math.ceil((theta_end -theta_start) / step_size)


# initializing theta

theta= theta_start
# calculate x and y cooradinates

for i in range(steps):

  x.append(a*math.cos(theta)+center[0]) # x= a*cos(θ) +p

  y.append(b*math.sin(theta)+center[1]) # y=b*sin(θ) +q

  theta += step_size # incremet the theta by step_size


# Plotting

plt.figure()

# plot the center point

plt.plot(center[0],center[1],'.')

#Plot the ellipse

plt.plot(x,y,'-')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

plt.title("Ellipse centered at (2,2) with a=3 , b=5")


# Equal aspect ration to avoid stretching

ax= plt.gca()

ax.set_aspect('equal',adjustable='box')

plt.show()

# %% [markdown]
# PARABOLA
# 4. Plot a Parabola (𝑦 − 𝑝) ^2= 4𝑎(𝑥 − 𝑞) with vertex at (𝑝,𝑞). The values of p, q, and a can be chosen appropriately.

# %%
import matplotlib.pyplot as plt

import math

# parabola parameters

q=0 # y-coordinate of vertex

p=0 # x-coordinate of vertex

a=0.5 # controls width and direction

# Step size for x values

step_size = 0.1

# define x range aroung vertex

y_start = p-5

y_end = p + 5

# lists to store coordinates

x_values =[]

y_values =[]

#initialize x

y = y_start

# generate poinst for parabola
while y <= y_end:

  x = 4*a*(y-p)**2+p

  x_values.append(x)

  y_values.append(y)

  y += step_size

#plot the graph

plt.figure()

plt.title(f"Parabola with vertex at ({p},{q}) and a ={a}")

plt.plot(x_values,y_values,'-')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

plt.show()

# %% [markdown]
# Exercise:
# 4. Draw the line represented by the function y=x.

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [i for i in x] # or y = x or y = [1,2,3,4]
plt.plot(x,y,marker="o")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
plt.show()

# %% [markdown]
# Exercise:
# 5. Draw a line in a diagram that joins the position (1, 3), (2, 8), (6, 1) and (8, 10).

# %%
import matplotlib.pyplot as plt
x = [1,2,6,8]
y = [3,8,1,10]
plt.plot(x,y,marker="x")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
plt.show()

# %% [markdown]
# Exercise:
# 6. Plot 20 values of x and y from the following functions.
#
# 𝑓(𝑥)=5𝑥3+2𝑥−1
#
# 𝑓(𝑥)=−2𝑥3+𝑥2+100
#
# 𝑓(𝑥)=2𝜋𝑥+20

# %%
import matplotlib.pyplot as plt
import math

#create a function to calculate y values
def functiona(x):
  result= 5*(x**3)+2*x-1
  return result
def functionb(x):
  result= -2*(x**3)+(x**2)+100
  return result
def functionc(x):
  result= (2*math.pi*x)+20
  return result


#defining empty lists
xCoord=[]
yCoord=[]

#loop over 20 values from 0 to 19, and calculate the matching values for #y using the function
for i in range(0,20):
  xCoord.append(i)
  yCoord.append(functiona(i))
plt.plot(xCoord,yCoord, marker='x',color='red',label='5*(x**3)+2*x-1')

xCoord=[]
yCoord=[]

for i in range(0,20):
  xCoord.append(i)
  yCoord.append(functionb(i))
plt.plot(xCoord,yCoord, marker='o',color='blue',label='-2*(x**3)+(x**2)+100')

xCoord=[]
yCoord=[]

for i in range(0,20):
  xCoord.append(i)
  yCoord.append(functionc(i))
plt.plot(xCoord,yCoord, marker='*',color='green',label='(2*math.pi*x)+20')
#function to add title
plt.title('Exercise 6')

#Function to label axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# function for the visibility of grid
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Exercise:
# 7. Plot all the graph from Q no 3 on the same pane using subplot.

# %%
import matplotlib.pyplot as plt
import math

#create a function to calculate y values
def functiona(x):
  result= 5*(x**3)+2*x-1
  return result
def functionb(x):
  result= -2*(x**3)+(x**2)+100
  return result
def functionc(x):
  result= (2*math.pi*x)+20
  return result


#defining empty lists
xCoord=[]
yCoord=[]

#loop over 20 values from 0 to 19, and calculate the matching values for #y using the function
plt.subplot(3,1,1)
plt.grid()
for i in range(0,20):
  xCoord.append(i)
  yCoord.append(functiona(i))
plt.plot(xCoord,yCoord, marker='x',color='red',label='5*(x**3)+2*x-1')
plt.legend()

xCoord=[]
yCoord=[]

plt.subplot(3,1,2)
plt.grid()
for i in range(0,20):
  xCoord.append(i)
  yCoord.append(functionb(i))
plt.plot(xCoord,yCoord, marker='o',color='blue',label='-2*(x**3)+(x**2)+100')
plt.legend()

xCoord=[]
yCoord=[]

plt.subplot(3,1,3)
for i in range(0,20):
  xCoord.append(i)
  yCoord.append(functionc(i))
plt.plot(xCoord,yCoord, marker='*',color='green',label='(2*math.pi*x)+20')
#function to add title
#plt.title('Exercise 6')

#Function to label axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# function for the visibility of grid
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Exercise:
# 8. Plot all the graph from Task 2 using subplot.

# %%
import matplotlib.pyplot as plt
day=[1,2,3,4,5]
enfield=[50,40,70,80,20]
honda=[80,20,20,50,60]
yamaha=[70,20,60,40,60]
ktm=[40,20,30,70,60]
plt.subplot(2,2,1)
plt.plot(day, enfield, marker='o', color='blue',label='Enfield', linewidth=1)
#function to add title
#plt.title('Distance Covered by Bikes(in Km)')
#Function to label axes
plt.xlabel('Days')
plt.ylabel('KM')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.subplot(2,2,2)
plt.plot(day, honda, marker='x', color='red',label='Honda', linewidth=1)
#function to add title
#plt.title('Distance Covered by Bikes(in Km)')
#Function to label axes
plt.xlabel('Days')
plt.ylabel('KM')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.subplot(2,2,3)
plt.plot(day, yamaha, marker='+', color='black',label='Yamaha', linewidth=1)
#function to add title
#plt.title('Distance Covered by Bikes(in Km)')
#Function to label axes
plt.xlabel('Days')
plt.ylabel('KM')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.subplot(2,2,4)
plt.plot(day, ktm, marker='*', color='orange',label='KTM', linewidth=1)
#function to add title
#plt.title('Distance Covered by Bikes(in Km)')
#Function to label axes
plt.xlabel('Days')
plt.ylabel('KM')
# Function to add a legend
plt.legend()
# function for the visibility of grid
plt.grid()
plt.show()

# %% [markdown]
# Exercise:
# 9. Plot the trigonometric COSINE function in interval [−3𝜋,3𝜋], i.e., 𝑦 = cos (𝑥), −3𝜋 ≤ 𝑥 ≤3𝜋

# %%
# Import necessary modules
# Using math module for pi and sin function
import matplotlib.pyplot as plt
import math

# Step 1: Generate equidistant x-coordinates between the given interval
# Lists for coordinates
x = []
y = []

# Define start, end, and step size for x increment
start = -3 * math.pi
end = 3 * math.pi
step = 0.1 # Controls smoothness of the graph
i = start
while i <= end:
  x.append(i) # Store x-coordinate

# Step 2: Calculate the y-coordinate using sin function for each x
  y.append(math.cos(i))
  i += step

# Step 3: Plot the graph using calculated coordinates
# Label the graph properly
plt.plot(x, y, color="red", label="cos function")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("y = cos(x) ,-3π<= x <= 3π")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Exercise:
# 10. Plot a circle with center at (a, b) and radius r. The values of a=b=2, and r=4, using a while loop.

# %%
import matplotlib.pyplot as plt
import math

# for a=b=2 and r = 4:
# Circle equation: x^2 + y^2 = r^2
# Paramateric equation:
# x =r*cos(theta) + a , and y = r*sin(theta) + b

x =[] # List to store x values
y= [] # List to store y values
r = 4
center = [2,2]

# paramater theta start value
theta_start = 0.0
# parameter Theta end value (bit more than 2pi)
theta_end = 2*math.pi

# step sizes to sample the paramater Theta
step_size= 0.125

#math.ceil() → round up to nearest integer
# Number of samples
steps = math.ceil((theta_end-theta_start)/step_size)

# initialize the theta
# variable to increment Theta by each step
theta = theta_start

# for loop to calculate x and y value at each steps
i = 0
while i<steps:
  x.append(r*math.cos(theta)+center[0])
  y.append(r*math.sin(theta)+center[1])
  theta += step_size
  i+=1

# create figure in new window
plt.figure()

# plot a dot a center
plt.plot(center[0],center[1],'.')

plt.plot(x,y,'-')
plt.grid()
plt.xlabel("X")
plt.ylabel("Y")

#plt.gca() → Get the current figure (axes object) for handling
ax =plt.gca()

#ensures 1 unit in x = 1 unit in y
#Without this ,figure is stretched(ircle could appear as an ellipse)
ax.set_aspect('equal',adjustable='box')
plt.show()

# %% [markdown]
# Exercise:
# 11. Plot the above circle and the ellipse on the same axes. This is give an idea about the intersection points of the two conic sections.

# %%
import matplotlib.pyplot as plt
import math

# for a=b=2 and r = 4:
# Circle equation: x^2 + y^2 = r^2
# Paramateric equation:
# x =r*cos(theta) + a , and y = r*sin(theta) + b

x =[] # List to store x values
y= [] # List to store y values
r = 4
center = [2,2]

# paramater theta start value
theta_start = 0.0
# parameter Theta end value (bit more than 2pi)
theta_end = 2*math.pi

# step sizes to sample the paramater Theta
step_size= 0.125

#math.ceil() → round up to nearest integer
# Number of samples
steps = math.ceil((theta_end-theta_start)/step_size)

# initialize the theta
# variable to increment Theta by each step
theta = theta_start

# for loop to calculate x and y value at each steps
i = 0
while i<steps:
  x.append(r*math.cos(theta)+center[0])
  y.append(r*math.sin(theta)+center[1])
  theta += step_size
  i+=1

# create figure in new window
#plt.figure()

# plot a dot a center
plt.plot(center[0],center[1],'.')

plt.plot(x,y,'-',label='Circle')
#plt.grid()
#plt.xlabel("X")
#plt.ylabel("Y")

#plt.gca() → Get the current figure (axes object) for handling
#ax =plt.gca()

#ensures 1 unit in x = 1 unit in y
#Without this ,figure is stretched(ircle could appear as an ellipse)
#ax.set_aspect('equal',adjustable='box')
#plt.show()

# Lists to store x and y values

x = []

y = []

# Ellipse parameters

a=3 # semi-minor axis

b=5 # semi-major axis

#center =[2,2] # center (p,q)


# Parameter theta

theta_start = 0.0

theta_end = 3*math.pi # make more than 2*pi

step_size = 0.125


# Number of samples

steps = math.ceil((theta_end -theta_start) / step_size)


# initializing theta

theta= theta_start
# calculate x and y cooradinates

for i in range(steps):

  x.append(a*math.cos(theta)+center[0]) # x= a*cos(θ) +p

  y.append(b*math.sin(theta)+center[1]) # y=b*sin(θ) +q

  theta += step_size # incremet the theta by step_size


# Plotting

#plt.figure()

# plot the center point

#plt.plot(center[0],center[1],'.')

#Plot the ellipse

plt.plot(x,y,'-',label='Ellipse')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

plt.title("Circle and Ellipse centered at (2,2)")


# Equal aspect ration to avoid stretching

ax= plt.gca()

ax.set_aspect('equal',adjustable='box')

plt.legend()
plt.show()

# %% [markdown]
# Example:
# 12. Plot a Parabola (𝑦 − 𝑝) = 4𝑎(𝑥 − 𝑞)^2 with vertex at (𝑝,𝑞). The values of p, q, and a can be chosen appropriately.

# %%
import matplotlib.pyplot as plt

import math

# parabola parameters

q=0 # x-coordinate of vertex

p=0 # y-coordinate of vertex

a=0.5 # controls width and direction

# Step size for x values

step_size = 0.1

# define x range aroung vertex

x_start = q-5

x_end = q + 5

# lists to store coordinates

x_values =[]

y_values =[]

#initialize x

x = x_start

# generate poinst for parabola
while x <= x_end:

  y = 4*a*(x-q)**2+p

  x_values.append(x)

  y_values.append(y)

  x += step_size

#plot the graph

plt.figure()

plt.title(f"Parabola with vertex at ({q},{p}) and a ={a}")

plt.plot(x_values,y_values,'-')

plt.grid()

plt.xlabel("X")

plt.ylabel("Y")

plt.show()
