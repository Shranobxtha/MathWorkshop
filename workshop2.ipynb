# %% [markdown]
# <a href="https://colab.research.google.com/github/Shranobxtha/MathWorkshop/blob/main/workshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python function that takes a list and returns a new list with distinct elements from the
# first list.
# Sample List : [1,2,3,3,3,3,4,5]
# Unique List : [1, 2, 3, 4, 5]

# %%
def distinct(list):
  x = [];
  for i in list:
    if i not in x:
      x.append(i);
  return x;

list = [];
n = int(input("Enter number of terms: "));
for i in range(n):
  ele = int(input("Enter elements for list: "));
  list.append(ele);
a = distinct(list);
print(a);
# Out:
# Enter number of terms: 8
# Enter elements for list: 1
# Enter elements for list: 2
# Enter elements for list: 3
# Enter elements for list: 3
# Enter elements for list: 3
# Enter elements for list: 3
# Enter elements for list: 4
# Enter elements for list: 5
# [1, 2, 3, 4, 5]

# %% [markdown]
# 2. Write a Python function that takes a number as a parameter and checks whether the number
# is prime or not.
