# %% [markdown]
# <a href="https://colab.research.google.com/github/Shranobxtha/MathWorkshop/blob/main/Workshop10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
def derivative(func, a, method, h):
  '''Compute the difference formula for f'(a) with step size h.
  Parameters
  ----------
  fun : function
  Vectorized function of one variable
  a : number
  Compute derivative at x = a
  method : string
  Difference formula: 'forward', 'backward' or 'central'
  h : number
  Step size in difference formula
  Returns
  -------
  float
  Difference formula:
  forward: f(a+h) - f(a))/h
  backward: f(a) - f(a-h))/h
  '''
  if method == 'forward':
    return (func(a + h) - func(a))/h
  elif method == 'backward':
    return (func(a) - func(a - h))/h
  elif method == 'central':
    return (func(a+h) - func(a-h))/(2*h)
  else:
    raise ValueError("Method must be 'central', 'forward' or'backward'.")
if __name__ == "__main__":
  # Let check our derivative function on simple functions.
  # For example, we know d/dx (cos(x)) = - sin(x) at 0 should
  # equal to zero.
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 0, method='forward', h=0.001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 0, method='forward', h=0.01)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 0, method='forward', h=0.0001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 1, method='forward', h=0.001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, -1, method='forward', h=0.001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 0, method='forward', h=0.001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 0, method='backward', h=0.001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  actual_value = -np.sin(0.0)
  result = derivative(np.cos, 0, method='central', h=0.001)
  print("Result = {:0.4f}".format(result))
  print("Error = {:0.04f}".format(np.abs(result - actual_value)))
  x = np.linspace(0,5*np.pi,100)
  actual_value = np.cos(x)
  result = derivative(np.sin, x, method='central', h=0.001)
  plt.plot(x, actual_value, 'b-', label='True Value')
  plt.plot(x, result, 'r.', label='Central Difference')
  plt.legend()
  plt.title("Central Difference Derivative of y = sin(x)")
  plt.grid(True)
  plt.show()
# Out:
# Result = -0.0005
# Error = 0.0005
# Result = -0.0050
# Error = 0.0050
# Result = -0.0000
# Error = 0.0000
# Result = -0.8417
# Error = 0.8417
# Result = 0.8412
# Error = 0.8412
# Result = -0.0005
# Error = 0.0005
# Result = 0.0005
# Error = 0.0005
# Result = 0.0000
# Error = 0.0000
